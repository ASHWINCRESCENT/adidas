# %% [markdown]
# # ADIDAS PROJECT

# %%
import pandas as pd

# %%
adidas_sales = pd.read_csv("adidas new.csv")

# %%
adidas_sales
# Out:
#       Unnamed: 0   Unnamed: 1             Unnamed: 2    Unnamed: 3 Unnamed: 4  \
# 0            NaN          NaN  Adidas Sales Database           NaN        NaN
# 1            NaN          NaN                    NaN           NaN        NaN
# 2            NaN          NaN                    NaN           NaN        NaN
# 3            NaN     Retailer            Retailer ID  Invoice Date     Region
# 4            NaN  Foot Locker                1185732    01/01/2020  Northeast
# ...          ...          ...                    ...           ...        ...
# 9647         NaN  Foot Locker                1185732    24/01/2021  Northeast
# 9648         NaN  Foot Locker                1185732    24/01/2021  Northeast
# 9649         NaN  Foot Locker                1185732    22/02/2021  Northeast
# 9650         NaN  Foot Locker                1185732    22/02/2021  Northeast
# 9651         NaN  Foot Locker                1185732    22/02/2021  Northeast
#
# ...
